# %% [markdown]
# # Pokemon Walls
# The objective is to find the best Pokemon walls by taking into account:
# - Physical/Special Defense stats;
# - Types, and their damage factors.

# %%
import pandas as pd
import pokemon_utilities

pokemons = pd.read_csv('Pokemons.csv').set_index('#')
types_chart = pd.read_csv('TypesChart.csv').set_index('Attack')

pokemons.loc[197].to_frame().T
# Out:
#         Name Type 1 Type 2 Total  HP Attack Defense Sp. Atk Sp. Def Speed  \
# 197  Umbreon   Dark    NaN   525  95     65     110      60     130    65
#
#     Generation Legendary
# 197          2     False

# %% [markdown]
# ## Types Factors and Damages

# %%
for type in types_chart.iloc[:,1:]:
    pokemons[type] = pokemon_utilities.calculate_type_damage_factors(types_chart, type, pokemons['Type 1'], pokemons['Type 2'])
    pokemons[type + ' Physical Damage'] = pokemon_utilities.calculate_damages(pokemons['Defense'], pokemons[type])
    pokemons[type + ' Special Damage'] = pokemon_utilities.calculate_damages(pokemons['Sp. Def'], pokemons[type])

# %% [markdown]
# ## Average Damages

# %%
pokemons['Physical Average Damage'] = pokemons.filter(like='Physical Damage').mean(axis=1)
pokemons['Special Average Damage'] = pokemons.filter(like='Special Damage').mean(axis=1)
pokemons['Mixed Average Damage'] = pokemons.filter(like='Damage').mean(axis=1)

# %% [markdown]
# ## Physical Walls

# %%
pokemons.sort_values('Physical Average Damage').filter(regex='Name|Average Damage').head(10)
# Out:
#            Name  Physical Average Damage  Special Average Damage  \
# #
# 208     Steelix                22.892941               66.713575
# 213     Shuckle                25.753964               25.753964
# 227    Skarmory                27.223529               52.917647
# 205  Forretress                31.935294               72.123529
# 91     Cloyster                32.684314              123.766667
# 110     Weezing                39.988235               67.164706
# 245     Suicune                42.904348               42.904348
# 99      Kingler                42.904348               96.080000
# 249       Lugia                43.238462               36.852941
# 232     Donphan                43.623529               85.129412
#
#      Mixed Average Damage
# #
# 208             44.803258
# 213             25.753964
# 227             40.070588
# 205             52.029412
# 91              78.225490
# 110             53.576471
# 245             42.904348
# 99              69.492174
# 249             40.045701
# 232             64.376471

# %% [markdown]
# ## Special Walls

# %%
pokemons.sort_values('Special Average Damage').filter(regex='Name|Average Damage').head(10)
# Out:
#            Name  Physical Average Damage  Special Average Damage  \
# #
# 213     Shuckle                25.753964               25.753964
# 250       Ho-oh                55.862745               33.502674
# 226     Mantine                71.235294               36.647059
# 242     Blissey               472.400000               36.844444
# 249       Lugia                43.238462               36.852941
# 73   Tentacruel                69.994570               38.776471
# 197     Umbreon                47.396791               40.430769
# 245     Suicune                42.904348               42.904348
# 122    Mr. Mime                77.650226               43.017647
# 143     Snorlax                74.369231               44.763636
#
#      Mixed Average Damage
# #
# 213             25.753964
# 250             44.682709
# 226             53.941176
# 242            254.622222
# 249             40.045701
# 73              54.385520
# 197             43.913780
# 245             42.904348
# 122             60.333937
# 143             59.566434

# %% [markdown]
# ## Mixed Walls

# %%
pokemons.sort_values('Mixed Average Damage').filter(regex='Name|Average Damage').head(10)
# Out:
#           Name  Physical Average Damage  Special Average Damage  \
# #
# 213    Shuckle                25.753964               25.753964
# 249      Lugia                43.238462               36.852941
# 227   Skarmory                27.223529               52.917647
# 245    Suicune                42.904348               42.904348
# 197    Umbreon                47.396791               40.430769
# 250      Ho-oh                55.862745               33.502674
# 208    Steelix                22.892941               66.713575
# 9    Blastoise                49.040000               46.800000
# 212     Scizor                43.991765               54.541176
# 145     Zapdos                52.281661               49.478431
#
#      Mixed Average Damage
# #
# 213             25.753964
# 249             40.045701
# 227             40.070588
# 245             42.904348
# 197             43.913780
# 250             44.682709
# 208             44.803258
# 9               47.920000
# 212             49.266471
# 145             50.880046
